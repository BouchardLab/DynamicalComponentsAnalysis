# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scipy.integrate
import synth_data

from imp import reload
reload(synth_data)
# Out:
# <module 'synth_data' from '/home/davidclark/Projects/ComplexityComponentsAnalysis/synth_data.py'>

# %%
N = 100
noise_cov = np.eye(N)*10
X = synth_data.gen_chaotic_rnn(N, 10, 0.001, 0.01, noise_cov=noise_cov)

# %%
plt.imshow(X[:200, :].T)
